# %% [markdown]
# ## Librerias

# %%
try:
    import pandas as pd
except ImportError:
    print("Pandas not installed")
    # %pip install pandas --user

try:
    import matplotlib.pyplot as plt
except ImportError:
    print("Matplotlib not installed")
    # %pip install matplotlib --user

import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura de datos
#
# - [Dataset Qatar 2022: https://www.kaggle.com/datasets/shrikrishnaparab/fifa-world-cup-2022-qatar-match-data](https://www.kaggle.com/datasets/shrikrishnaparab/fifa-world-cup-2022-qatar-match-data)

# %%
archivo = "https://raw.githubusercontent.com/IgnacioPardo/Tecnologias_Exponenciales_2025/refs/heads/main/qatar.csv"

# Leer datos del archivo
mundial : pd.DataFrame = pd.read_csv(archivo)
mundial
# Out:
#     match_no day_of_week       date   hour                          venue  \
# 0          1         Sun  20-Nov-22  17:00                Al Bayt Stadium
# 1          2         Mon  21-Nov-22  14:00  Khalifa International Stadium
# 2          3         Mon  21-Nov-22  17:00             Al Thumama Stadium
# 3          4         Mon  21-Nov-22  20:00          Ahmed bin Ali Stadium
# 4          5         Tue  22-Nov-22  11:00          Lusail Iconic Stadium
# ..       ...         ...        ...    ...                            ...
# 59        60         Sat  10-Dec-22  20:00                Al Bayt Stadium
# 60        61         Tue  13-Dec-22  20:00          Lusail Iconic Stadium
# 61        62         Wed  14-Dec-22  20:00                Al Bayt Stadium
# 62        63         Sat  17-Dec-22  16:00  Khalifa International Stadium
# 63        64         Sun  18-Dec-22  16:00          Lusail Iconic Stadium
#
#                           referee                     group              1  \
# ...

# %%
partidos = mundial['match_no'].max()
partidos
# Out:
# 64

# %%
mundial.info()
mundial.describe()
mundial.columns
mundial.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 59 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   match_no                         64 non-null     int64
#  1   day_of_week                      64 non-null     object
#  2   date                             64 non-null     object
#  3   hour                             64 non-null     object
#  4   venue                            64 non-null     object
#  5   referee                          64 non-null     object
#  6   group                            64 non-null     object
#  7   1                                64 non-null     object
#  8   2                                64 non-null     object
#  9   attendance                       64 non-null     int64
#  10  1_xg                             64 non-null     float64
#  11  2_xg                             64 non-null     float64
# ...

# %% [markdown]
# ## Analisis

# %% [markdown]
# ### Primera Parte

# %%
len(mundial["1"].unique())
# Out:
# 32

# %%
mundial["group"].nunique()
# Out:
# 13

# %%
mundial['attendance'].mean()
# Out:
# np.float64(53191.4375)

# %%
diferencia = mundial["1_goals"] - mundial["2_goals"]
diferencia.max()
# Out:
# 7

# %%
# Cual es la selección que mas penales metió?
# Completar
local = mundial.groupby('1')['1_panelties_scored'].sum()
visitante = mundial.groupby('2')['2_panelties_scored'].sum()
totales = local.add(visitante, fill_value=0)
print(totales.idxmax())
# Out:
# ARGENTINA

# %%
# Cual es la selección que mas penales le hicieron?
# Completar

penales_recibidos_local = mundial.groupby('1')['2_panelties_scored'].sum()
penales_recibidos_visitante = mundial.groupby('2')['1_panelties_scored'].sum()
penales_recibidos = penales_recibidos_local.add(penales_recibidos_visitante, fill_value=0)
print(penales_recibidos.idxmax())
# Out:
# FRANCE

# %% [markdown]
# ### Segunda Parte

# %%
equipo : str = "ARGENTINA"

# %%
# Seleccionar todos los partidos que jugo el equipo de "local"
# Completar

filtroLocal : pd.Series = mundial['1'] == equipo
mundial[filtroLocal]
# Out:
#     match_no day_of_week       date   hour                  venue  \
# 4          5         Tue  22-Nov-22  11:00  Lusail Iconic Stadium
# 23        24         Sat  26-Nov-22  20:00  Lusail Iconic Stadium
# 49        50         Sat   3-Dec-22  20:00  Ahmed bin Ali Stadium
# 60        61         Tue  13-Dec-22  20:00  Lusail Iconic Stadium
# 63        64         Sun  18-Dec-22  16:00  Lusail Iconic Stadium
#
#              referee        group          1             2  attendance  ...  \
# 4      Slavko Vincic      Group C  ARGENTINA  SAUDI ARABIA       88012  ...
# 23    Daniele Orsato      Group C  ARGENTINA        MEXICO       88966  ...
# 49  Szymon Marciniak  Round of 16  ARGENTINA     AUSTRALIA       45032  ...
# 60    Daniele Orsato   Semi-Final  ARGENTINA       CROATIA       88966  ...
# 63  Szymon Marciniak        Final  ARGENTINA        FRANCE       88966  ...
#
#     1_panelties_scored  2_panelties_scored  1_goal_prevented  \
# ...

# %%
# Seleccionar todos los partidos que jugo el equipo de "visitante"
# Completar

filtroVisitante : pd.Series = mundial['2'] == equipo
mundial[filtroVisitante]
# Out:
#     match_no day_of_week       date   hour                  venue  \
# 38        39         Wed  30-Nov-22  20:00  Lusail Iconic Stadium
# 57        58         Fri   9-Dec-22  20:00  Lusail Iconic Stadium
#
#                 referee          group            1          2  attendance  \
# 38       Michael Oliver        Group C       POLAND  ARGENTINA       84985
# 57  Antonio Mateu Lahoz  Quarter-final  NETHERLANDS  ARGENTINA       88235
#
#     ...  1_panelties_scored  2_panelties_scored  1_goal_prevented  \
# 38  ...                   0                   0                25
# 57  ...                   0                   1                15
#
#     2_goal_prevented  1_own_goal  2_own_goal 1_forced_turnovers  \
# 38                 4           0           0                 67
# 57                 5           0           0                 91
#
#     2_forced_turnovers  1_defensive_pressure_applied  \
# 38                  48                           438
# ...

# %%
# Seleccionar todos los partidos que jugo el equipo (de "local" o "visitante")
# Completar

partidos : pd.DataFrame = pd.concat([mundial[filtroLocal], mundial[filtroVisitante]])
partidos
# Out:
#     match_no day_of_week       date   hour                  venue  \
# 4          5         Tue  22-Nov-22  11:00  Lusail Iconic Stadium
# 23        24         Sat  26-Nov-22  20:00  Lusail Iconic Stadium
# 49        50         Sat   3-Dec-22  20:00  Ahmed bin Ali Stadium
# 60        61         Tue  13-Dec-22  20:00  Lusail Iconic Stadium
# 63        64         Sun  18-Dec-22  16:00  Lusail Iconic Stadium
# 38        39         Wed  30-Nov-22  20:00  Lusail Iconic Stadium
# 57        58         Fri   9-Dec-22  20:00  Lusail Iconic Stadium
#
#                 referee          group            1             2  attendance  \
# 4         Slavko Vincic        Group C    ARGENTINA  SAUDI ARABIA       88012
# 23       Daniele Orsato        Group C    ARGENTINA        MEXICO       88966
# 49     Szymon Marciniak    Round of 16    ARGENTINA     AUSTRALIA       45032
# 60       Daniele Orsato     Semi-Final    ARGENTINA       CROATIA       88966
# ...

# %%
# Cuantos goles hizo el equipo en total (obtener los goles metidos de local y sumarlos con los goles metidos de visitante)
# Completar

goles : int = mundial.loc[filtroLocal, '1_goals'].sum() + mundial.loc[filtroVisitante, '2_goals'].sum()
goles
# Out:
# np.int64(15)

# %%
# Cuantos goles hizo el equipo en promedio
# Completar
prom = goles / len(partidos)
prom
# Out:
# np.float64(2.142857142857143)

# %%
# Cuantos partidos gano el equipo
# Completar

ganados : int = len(mundial[filtroLocal & (mundial['1_goals'] > mundial['2_goals'])]) + len(mundial[filtroVisitante & (mundial['2_goals'] > mundial['1_goals'])])
ganados
# Out:
# 4

# %%
# Graficar los goles hechos por el equipo en cada partido

goles_partido = pd.concat([mundial[mundial["1"] == equipo]['1_goals'], mundial[mundial["2"] == equipo]['2_goals']]).sort_index()

fig, ax = plt.subplots()
ax.bar(range(1, len(goles_partido) + 1), goles_partido.values)
ax.set_title(equipo)
plt.show()

# %% [markdown]
# ### Tercera Parte

# %%
# Contar cuantos goles hizo cada equipo en total en el mundial
# Completar

goles_como_local = mundial.groupby('1')['1_goals'].sum()
goles_como_visitante = mundial.groupby('2')['2_goals'].sum()
goles_por_equipo = goles_como_local.add(goles_como_visitante, fill_value=0).sort_values(ascending=False)

equipos = goles_por_equipo.index.tolist()
goles = goles_por_equipo.values.tolist()
# Out:
# [16,
#  15,
#  13,
#  12,
#  10,
#  9,
#  8,
#  8,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1]

# %%
# Graficar los goles por equipo en todo el mundial
fig, ax = plt.subplots(figsize=(14, 6))
ax.bar(equipos, goles)
plt.xticks(rotation=60, ha='right', fontsize=8)
plt.show()
# Completar

# %%
# Cual es el equipo que hizo mas goles en el mundial?
# Completar
print(goles_por_equipo.idxmax())
# Out:
# FRANCE

# %%
# Por cada partido, cual fue la diferencia de goles?
# Completar
mundial['diferencia_goles'] = abs(mundial['1_goals'] - mundial['2_goals'])
mundial[['1', '2', 'diferencia_goles']]
# Out:
#                 1             2  diferencia_goles
# 0           QATAR       ECUADOR                 2
# 1         ENGLAND          IRAN                 4
# 2         SENEGAL   NETHERLANDS                 2
# 3   UNITED STATES         WALES                 0
# 4       ARGENTINA  SAUDI ARABIA                 1
# ..            ...           ...               ...
# 59        ENGLAND        FRANCE                 1
# 60      ARGENTINA       CROATIA                 3
# 61         FRANCE       MOROCCO                 2
# 62        CROATIA       MOROCCO                 1
# 63      ARGENTINA        FRANCE                 0
#
# [64 rows x 3 columns]

# %%
# Por cada partido, cual fue el equipo que gano?
# Completar
def ganador(row):
    if row['1_goals'] > row['2_goals']:
        return row['1']
    elif row['2_goals'] > row['1_goals']:
        return row['2']
    else:
        return 'Empate'

mundial['ganador'] = mundial.apply(ganador, axis=1)
mundial[['1', '2', 'ganador']]
# Out:
#                 1             2       ganador
# 0           QATAR       ECUADOR       ECUADOR
# 1         ENGLAND          IRAN       ENGLAND
# 2         SENEGAL   NETHERLANDS   NETHERLANDS
# 3   UNITED STATES         WALES        Empate
# 4       ARGENTINA  SAUDI ARABIA  SAUDI ARABIA
# ..            ...           ...           ...
# 59        ENGLAND        FRANCE        FRANCE
# 60      ARGENTINA       CROATIA     ARGENTINA
# 61         FRANCE       MOROCCO        FRANCE
# 62        CROATIA       MOROCCO       CROATIA
# 63      ARGENTINA        FRANCE        Empate
#
# [64 rows x 3 columns]

# %%
# En cada fase del mundial, cual fue el equipo que hizo mas goles?
# Completar
# En cada fase del mundial, cual fue el equipo que hizo mas goles?
# Completar
mundial["group"] = mundial["group"].apply(
    lambda x: "group" if "Group" in x else x
)

fases = mundial["group"].unique()
resultado = []
for fase in fases:
    partidos = mundial[mundial["group"] == fase]

    goles = {}

    for i in range(len(partidos)):
        equipo1 = partidos.iloc[i]["1"]
        equipo2 = partidos.iloc[i]["2"]

        goles[equipo1] = goles.get(equipo1, 0) + partidos.iloc[i]["1_goals"]
        goles[equipo2] = goles.get(equipo2, 0) + partidos.iloc[i]["2_goals"]

    ganador = max(goles, key=goles.get)
    resultado.append({"fase": fase, "equipo": ganador, "goles": goles[ganador]})

max_goles_fase = pd.DataFrame(resultado)
max_goles_fase
# Out:
#                        fase       equipo  goles
# 0                     group      ENGLAND      9
# 1               Round of 16     PORTUGAL      6
# 2             Quarter-final  NETHERLANDS      2
# 3                Semi-Final    ARGENTINA      3
# 4  Play-off for third place      CROATIA      2
# 5                     Final    ARGENTINA      3

# %% [markdown]
# ### Tercera Parte

# %%
# Armar un gráfico a partir de algun nuevo análisis que se te ocurra
# Completar
attendance_por_fase = mundial.groupby('group')['attendance'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(attendance_por_fase.index, attendance_por_fase.values)
ax.set_title('Attendance por fase')
plt.xticks(rotation=45, ha='right')
plt.show()
